# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
h_df=pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
h_df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
h_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
h_df.shape
# Out:
# (5110, 12)

# %%
h_df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
h_df[h_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
h_df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
h_df['bmi'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
h_df['bmi'].plot(kind='box')
# Out:
# <Axes: >

# %%
h_df['bmi'].median()
# Out:
# 28.1

# %%
h_df['bmi']=h_df['bmi'].fillna(h_df['bmi'].median())

# %%
h_df.shape
# Out:
# (5110, 12)

# %%
h_df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
h_df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.862035     0.048728
# std            45.283560     7.699562     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.800000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
h_df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
h_df['stroke_cat']=h_df['stroke'].apply(lambda x: 'YES' if x==1 else 'NO')

# %%
h_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke stroke_cat
# 0       1        YES
# 1       1        YES
# 2       1        YES
# 3       1        YES
# ...

# %%
num_col=h_df.select_dtypes(include=np.number).columns
cat_col=h_df.select_dtypes(exclude=np.number).columns

# %%
num_col
# Out:
# Index(['id', 'age', 'hypertension', 'heart_disease', 'avg_glucose_level',
#        'bmi', 'stroke'],
#       dtype='object')

# %%
cat_col
# Out:
# Index(['gender', 'ever_married', 'work_type', 'Residence_type',
#        'smoking_status', 'stroke_cat'],
#       dtype='object')

# %%
h_df['age'].plot(kind='box')
# Out:
# <Axes: >

# %%
fig,axes=plt.subplots(ncols=5, figsize=(12,3))
for column, axis in zip(num_col[1:6],axes):
    sns.boxplot(data=h_df[column],ax=axis)
    axis.set_title(column)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.hist(h_df.age)
plt.show()# histogram for age

# %%
for col in num_col[1:6]:
    plt.figure(figsize=(4,3))
    plt.hist(h_df[col])
    plt.title(col)
    plt.show()

# %%
h_df[['age', 'hypertension', 'heart_disease', 'avg_glucose_level',
       'bmi']].corr()
# Out:
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.276398       0.263796           0.238171
# hypertension       0.276398      1.000000       0.108306           0.174474
# heart_disease      0.263796      0.108306       1.000000           0.161857
# avg_glucose_level  0.238171      0.174474       0.161857           1.000000
# bmi                0.324296      0.158293       0.036916           0.166876
#
#                         bmi
# age                0.324296
# hypertension       0.158293
# heart_disease      0.036916
# avg_glucose_level  0.166876
# bmi                1.000000

# %%
correlation_matrix=h_df[['age', 'hypertension', 'heart_disease', 'avg_glucose_level',
       'bmi']].corr()
correlation_matrix
# Out:
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.276398       0.263796           0.238171
# hypertension       0.276398      1.000000       0.108306           0.174474
# heart_disease      0.263796      0.108306       1.000000           0.161857
# avg_glucose_level  0.238171      0.174474       0.161857           1.000000
# bmi                0.324296      0.158293       0.036916           0.166876
#
#                         bmi
# age                0.324296
# hypertension       0.158293
# heart_disease      0.036916
# avg_glucose_level  0.166876
# bmi                1.000000

# %%
sns.heatmap(correlation_matrix,annot=True)
# Out:
# <Axes: >

# %%
cat_col
# Out:
# Index(['gender', 'ever_married', 'work_type', 'Residence_type',
#        'smoking_status', 'stroke_cat'],
#       dtype='object')

# %%
h_df['stroke'].value_counts()
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,3))
x=h_df['gender'].value_counts().plot(kind='bar')
for i in x.containers:
    x.bar_label(i)

# %%
for col in cat_col:
    plt.figure(figsize=(4,5))
    x=h_df[col].value_counts().plot(kind='bar')
    for i in x.containers:
        x.bar_label(i)
    plt.show()

# %%
max_age=h_df['age'].max()
max_age
# Out:
# 82.0

# %%
h_df[h_df['age']==max_age]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 23    64778    Male  82.0             0              1          Yes
# 32    39373  Female  82.0             1              0          Yes
# 35      712  Female  82.0             1              1           No
# 42    61960    Male  82.0             0              1          Yes
# 56    38829  Female  82.0             0              0          Yes
# 128   37132    Male  82.0             0              0          Yes
# 140   20439    Male  82.0             0              1          Yes
# 187   67895  Female  82.0             1              1          Yes
# 188   30184    Male  82.0             0              0          Yes
# 337   56357  Female  82.0             0              1           No
# 613   22853    Male  82.0             0              0           No
# 670   53010    Male  82.0             0              0          Yes
# 767   62382    Male  82.0             0              0          Yes
# ...

# %%
min_age=h_df['age'].min()
min_age
# Out:
# 0.08

# %%
h_df[h_df['age']==min_age]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married work_type  \
# 1614  47350  Female  0.08             0              0           No  children
# 3295  29955    Male  0.08             0              0           No  children
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke stroke_cat
# 1614          Urban             139.67  14.1        Unknown       0         NO
# 3295          Rural              70.33  16.9        Unknown       0         NO

# %%
def Get_Age_Group(age):

 if age <= 20:
  return "< 20"
 if age >20 and age <= 30:
    return "21-30"
 if age >30 and age <= 40:
    return "31-40"
 if age >40 and age <= 50: 
    return "41-50"
 if age > 50 and age <= 60:
    return "51-60"
 if age > 60 and age <= 70:
    return "61-70"
 if age >70 and age <= 80: 
    return "71-80"
 else:
    return "> 80"

# %%
h_df['Age_group']=h_df['age'].apply(lambda x:Get_Age_Group(x))

# %%
h_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke stroke_cat Age_group
# 0       1        YES     61-70
# 1       1        YES     61-70
# 2       1        YES     71-80
# ...

# %%
ax=h_df['Age_group'].value_counts().plot(kind='bar')
for i in ax.containers:
    ax.bar_label(i)

# %%
h_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke stroke_cat Age_group
# 0       1        YES     61-70
# 1       1        YES     61-70
# 2       1        YES     71-80
# ...

# %%
h_df.groupby(['Age_group'])['stroke'].sum()
# Out:
# Age_group
# 21-30      0
# 31-40      6
# 41-50     15
# 51-60     49
# 61-70     49
# 71-80    105
# < 20       2
# > 80      23
# Name: stroke, dtype: int64

# %%
h_df.groupby(['Age_group'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#   Age_group        bmi  avg_glucose_level        age
# 0     21-30  28.516514          94.096165  25.563303
# 1     31-40  31.102967          98.938190  35.538576
# 2     41-50  31.320704         101.011164  45.569689
# 3     51-60  31.746537         114.155310  55.340219
# 4     61-70  30.812458         119.687222  65.021886
# 5     71-80  29.042424         124.099108  76.042088
# 6      < 20  22.347415          94.345210  10.280976
# 7      > 80  27.989655         123.602500  81.482759

# %%
grouped_data = h_df.groupby(['Age_group'])[['bmi','avg_glucose_level']].mean().reset_index()

# Plotting with different colors
ax = grouped_data.plot(
    x='Age_group', 
    kind='bar', 
    color=['skyblue', 'lightcoral', 'lightgreen'], 
    edgecolor='black'
)
plt.title('Average BMI, Glucose Level, and Age by Age_Group')
plt.xlabel('Age_group')
plt.ylabel('Average Values')
plt.legend(title='Metrics', labels=['BMI', 'Avg Glucose Level', 'Age'])
plt.show()

# %%
h_df.groupby(['stroke'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    stroke        bmi  avg_glucose_level        age
# 0       0  28.799115         104.795513  41.971545
# 1       1  30.090361         132.544739  67.728193

# %%
grouped_data = h_df.groupby(['stroke'])[['bmi','avg_glucose_level','age']].mean().reset_index()

# Plotting with different colors
ax = grouped_data.plot(
    x='stroke', 
    kind='bar', 
    color=['skyblue', 'lightcoral', 'lightgreen'], 
    edgecolor='black'
)
plt.title('Average BMI, Glucose Level, and Age by Stroke')
plt.xlabel('stroke')
plt.ylabel('Average Values')
plt.legend(title='Metrics', labels=['BMI', 'Avg Glucose Level', 'Age'])
plt.show()

# %%
h_df.groupby(['ever_married'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#   ever_married        bmi  avg_glucose_level        age
# 0           No  25.300114           96.44815  22.014229
# 1          Yes  30.728512          111.23031  54.342082

# %%
grouped_data = h_df.groupby(['ever_married'])[['bmi','avg_glucose_level','age']].mean().reset_index()

# Plotting with different colors
ax = grouped_data.plot(
    x='ever_married', 
    kind='bar', 
    color=['skyblue', 'lightcoral', 'lightgreen'], 
    edgecolor='black'
)
plt.title('Average BMI, Glucose Level, and Age by Ever_Married')
plt.xlabel('ever_married')
plt.ylabel('Average Values')
plt.legend(title='Metrics', labels=['BMI', 'Avg Glucose Level', 'Age'])
plt.show()

# %%
h_df.groupby(['work_type'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#        work_type        bmi  avg_glucose_level        age
# 0       Govt_job  30.422527         107.779772  50.879756
# 1   Never_worked  25.545455          96.042727  16.181818
# 2        Private  30.218701         106.796844  45.503932
# 3  Self-employed  30.098413         112.645446  60.201465
# 4       children  20.225764          94.400277   6.841339

# %%
grouped_data = h_df.groupby(['work_type'])[['bmi','avg_glucose_level','age']].mean().reset_index()

# Plotting with different colors
ax = grouped_data.plot(
    x='work_type', 
    kind='bar', 
    color=['skyblue', 'lightcoral', 'lightgreen'], 
    edgecolor='black'
)
plt.title('Average BMI, Glucose Level, and Age by Work_type')
plt.xlabel('work_type')
plt.ylabel('Average Values')
plt.legend(title='Metrics', labels=['BMI', 'Avg Glucose Level', 'Age'])
plt.show()

# %%
h_df.groupby(['Residence_type'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#   Residence_type        bmi  avg_glucose_level        age
# 0          Rural  28.864200         106.375235  42.900811
# 1          Urban  28.859938         105.927307  43.542126

# %%
# df = pd.DataFrame(data)

grouped_data = h_df.groupby('Residence_type')[['bmi', 'avg_glucose_level', 'age']].mean().reset_index()

# Plotting with different colors
ax = grouped_data.plot(
    x='Residence_type', 
    kind='bar', 
    color=['skyblue', 'lightcoral', 'lightgreen'], 
    edgecolor='black'
)
plt.title('Average BMI, Glucose Level, and Age by Residence_type')
plt.xlabel('Residence Type')
plt.ylabel('Average Values')
plt.legend(title='Metrics', labels=['BMI', 'Avg Glucose Level', 'Age'])
plt.show()

# %%
h_df.groupby(['smoking_status'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#     smoking_status        bmi  avg_glucose_level        age
# 0          Unknown  25.762500          99.601541  30.229922
# 1  formerly smoked  30.603616         112.886079  54.929944
# 2     never smoked  29.942759         107.558092  46.744715
# 3           smokes  30.382510         108.017440  47.096324

# %%
grouped_data = h_df.groupby('smoking_status')[['bmi', 'avg_glucose_level', 'age']].mean().reset_index()

# Plotting with different colors
ax = grouped_data.plot(
    x='smoking_status', 
    kind='bar', 
    color=['skyblue', 'lightcoral', 'lightgreen'], 
    edgecolor='black'
)
plt.title('Average BMI, Glucose Level, and Age by smoking_status')
plt.xlabel('smoking_status')
plt.ylabel('Average Values')
plt.legend(title='Metrics', labels=['BMI', 'Avg Glucose Level', 'Age'])
plt.show()

# %%
h_df.groupby(['gender'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    gender        bmi  avg_glucose_level        age
# 0  Female  29.034469         104.057809  43.757395
# 1    Male  28.620993         109.088520  42.483385
# 2   Other  22.400000         143.330000  26.000000

# %%
# Group data by gender and calculate mean for BMI, glucose level, and age
grouped_data = h_df.groupby(['gender'])[['bmi', 'avg_glucose_level', 'age']].mean().reset_index()

# Define colors for each metric
colors = ['skyblue', 'lightcoral', 'lightgreen']

# Plot with distinct colors for each bar
ax = grouped_data.plot(
    x='gender', 
    kind='bar', 
    color=colors, 
    edgecolor='black'
)

# Set title, labels, and legend
plt.title('Average BMI, Glucose Level, and Age by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Values')
plt.legend(title='Metrics', labels=['BMI', 'Avg Glucose Level', 'Age'])
plt.show()

# %%
h_df.groupby(['stroke','gender'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    stroke  gender        bmi  avg_glucose_level        age
# 0       0  Female  28.991553         103.051753  42.601935
# 1       0    Male  28.528749         107.255112  41.083388
# 2       0   Other  22.400000         143.330000  26.000000
# 3       1  Female  29.902837         124.414397  67.137021
# 4       1    Male  30.335185         143.159352  68.500000

# %%
import matplotlib.pyplot as plt

# Group data by stroke and gender, calculating the mean for BMI, glucose level, and age
grouped_data = h_df.groupby(['stroke', 'gender'])[['bmi', 'avg_glucose_level', 'age']].mean().reset_index()

# Set up a color map for stroke status
stroke_colors = {0: 'skyblue', 1: 'lightcoral'}

# Set up a grid of subplots for each metric
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

# Plot each metric in a separate subplot
for i, metric in enumerate(['bmi', 'avg_glucose_level', 'age']):
    # Create a pivoted DataFrame for plotting
    pivoted_data = grouped_data.pivot(index='gender', columns='stroke')[metric]
    
    # Plot bars for each stroke status with assigned colors
    bars = pivoted_data.plot(
        kind='bar', 
        color=[stroke_colors[status] for status in pivoted_data.columns],
        edgecolor='black', 
        ax=axes[i]
    )
    
    # Add labels on top of each bar
    for container in bars.containers:
        bars.bar_label(container, fmt='%.2f', label_type='edge', padding=3)
    
    
    axes[i].set_title(f'Average {metric.capitalize()} by Stroke and Gender')
    axes[i].set_xlabel('Gender')
    axes[i].set_ylabel('Average Value' if i == 0 else '')
    axes[i].legend(title='Stroke Status', labels=['No Stroke', 'Stroke'])
    axes[i].tick_params(axis='x', rotation=45)


plt.suptitle('Average BMI, Glucose Level, and Age by Stroke Status and Gender', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
h_df.groupby(['stroke','smoking_status'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    stroke   smoking_status        bmi  avg_glucose_level        age
# 0       0          Unknown  25.664863          98.810127  29.112011
# 1       0  formerly smoked  30.614847         111.175092  53.753374
# 2       0     never smoked  29.925749         106.292042  45.567703
# 3       0           smokes  30.381392         106.219906  46.212851
# 4       1          Unknown  28.872340         124.808936  65.836596
# 5       1  formerly smoked  30.472857         132.806857  68.628571
# 6       1     never smoked  30.283333         132.907222  70.311111
# 7       1           smokes  30.402381         139.987857  62.809524

# %%
grouped_data = h_df.groupby(['stroke', 'smoking_status'])[['bmi', 'avg_glucose_level', 'age']].mean().reset_index()


stroke_colors = {0: 'skyblue', 1: 'lightcoral'}


fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)


for i, metric in enumerate(['bmi', 'avg_glucose_level', 'age']):
    
    pivoted_data = grouped_data.pivot(index='smoking_status', columns='stroke')[metric]
    
   
    bars = pivoted_data.plot(
        kind='bar', 
        color=[stroke_colors[status] for status in pivoted_data.columns],
        edgecolor='black', 
        ax=axes[i]
    )
    
    
    for container in bars.containers:
        bars.bar_label(container, fmt='%.2f', label_type='edge', padding=3)
    
    axes[i].set_title(f'Average {metric.capitalize()} by Stroke and Smoking Status')
    axes[i].set_xlabel('Smoking Status')
    axes[i].set_ylabel('Average Value' if i == 0 else '')
    axes[i].legend(title='Stroke Status', labels=['No Stroke', 'Stroke'])
    axes[i].tick_params(axis='x', rotation=45)


plt.suptitle('Average BMI, Glucose Level, and Age by Stroke Status and Smoking Status', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
h_df.groupby(['stroke','work_type'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    stroke      work_type        bmi  avg_glucose_level        age
# 0       0       Govt_job  30.488622         106.275881  50.056090
# 1       0   Never_worked  25.545455          96.042727  16.181818
# 2       0        Private  30.197118         105.113022  44.337176
# 3       0  Self-employed  30.162202         112.020504  59.241379
# 4       0       children  20.198686          94.488599   6.838949
# 5       1       Govt_job  29.172727         136.216970  66.454545
# 6       1        Private  30.620805         138.167919  67.241611
# 7       1  Self-employed  29.358462         119.894769  71.338462
# 8       1       children  29.500000          64.150000   7.660000

# %%
grouped_data = h_df.groupby(['stroke', 'work_type'])[['bmi', 'avg_glucose_level', 'age']].mean().reset_index()


stroke_colors = {0: 'skyblue', 1: 'lightcoral'}


fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)


for i, metric in enumerate(['bmi', 'avg_glucose_level', 'age']):
    # Create a pivoted DataFrame for plotting
    pivoted_data = grouped_data.pivot(index='work_type', columns='stroke')[metric]
    
    
    bars = pivoted_data.plot(
        kind='bar', 
        color=[stroke_colors[status] for status in pivoted_data.columns],
        edgecolor='black', 
        ax=axes[i]
    )
    
    
    for container in bars.containers:
        bars.bar_label(container, fmt='%.2f', label_type='edge', padding=3)
    
   
    axes[i].set_title(f'Average {metric.capitalize()} by Stroke and Work Type')
    axes[i].set_xlabel('Work Type')
    axes[i].set_ylabel('Average Value' if i == 0 else '')
    axes[i].legend(title='Stroke Status', labels=['No Stroke', 'Stroke'])
    axes[i].tick_params(axis='x', rotation=45)


plt.suptitle('Average BMI, Glucose Level, and Age by Stroke Status and Work Type', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
h_df.groupby(['stroke','Residence_type'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    stroke Residence_type        bmi  avg_glucose_level        age
# 0       0          Rural  28.818292         105.245746  41.729017
# 1       0          Urban  28.780414         104.356440  42.208062
# 2       1          Rural  29.830702         130.153947  67.570175
# 3       1          Urban  30.309630         134.563630  67.861630

# %%
import matplotlib.pyplot as plt


grouped_data = h_df.groupby(['stroke', 'Residence_type'])[['bmi', 'avg_glucose_level', 'age']].mean().reset_index()

# Define colors for each stroke status
stroke_colors = {0: 'skyblue', 1: 'lightcoral'}

fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)


for i, metric in enumerate(['bmi', 'avg_glucose_level', 'age']):
   
    pivoted_data = grouped_data.pivot(index='Residence_type', columns='stroke')[metric]
    
 
    bars = pivoted_data.plot(
        kind='bar', 
        color=[stroke_colors[status] for status in pivoted_data.columns],
        edgecolor='black', 
        ax=axes[i]
    )
    
    
    for container in bars.containers:
        bars.bar_label(container, fmt='%.2f', label_type='edge', padding=3)
    
  
    axes[i].set_title(f'Average {metric.capitalize()} by Stroke and Residence Type')
    axes[i].set_xlabel('Residence Type')
    axes[i].set_ylabel('Average Value' if i == 0 else '')
    axes[i].legend(title='Stroke Status', labels=['No Stroke', 'Stroke'])
    axes[i].tick_params(axis='x', rotation=45)


plt.suptitle('Average BMI, Glucose Level, and Age by Stroke Status and Residence Type', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
h_df.groupby(['stroke','ever_married'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    stroke ever_married        bmi  avg_glucose_level        age
# 0       0           No  25.228877          96.280208  21.286852
# 1       0          Yes  30.768273         109.492113  53.380147
# 2       1           No  29.544828         106.455172  65.355862
# 3       1          Yes  30.162273         135.983818  68.040909

# %%
grouped_data = h_df.groupby(['stroke', 'ever_married'])[['bmi', 'avg_glucose_level', 'age']].mean().reset_index()


stroke_colors = {0: 'skyblue', 1: 'lightcoral'}


fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)


for i, metric in enumerate(['bmi', 'avg_glucose_level', 'age']):
    
    pivoted_data = grouped_data.pivot(index='ever_married', columns='stroke')[metric]
    
    
    bars = pivoted_data.plot(
        kind='bar', 
        color=[stroke_colors[status] for status in pivoted_data.columns],
        edgecolor='black', 
        ax=axes[i]
    )
    
   
    for container in bars.containers:
        bars.bar_label(container, fmt='%.2f', label_type='edge', padding=3)
    
    
    axes[i].set_title(f'Average {metric.capitalize()} by Stroke and Marital Status')
    axes[i].set_xlabel('Marital Status')
    axes[i].set_ylabel('Average Value' if i == 0 else '')
    axes[i].legend(title='Stroke Status', labels=['No Stroke', 'Stroke'])
    axes[i].tick_params(axis='x', rotation=45)


plt.suptitle('Average BMI, Glucose Level, and Age by Stroke Status and Marital Status', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
num_col=['age','bmi','avg_glucose_level']

# %%
corr_matrix=h_df[num_col].corr()
corr_matrix
# Out:
#                         age       bmi  avg_glucose_level
# age                1.000000  0.324296           0.238171
# bmi                0.324296  1.000000           0.166876
# avg_glucose_level  0.238171  0.166876           1.000000

# %%
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(6,3))
plt.scatter(h_df.age,h_df.avg_glucose_level)
plt.title('Age vs Glucose Level')
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.scatter(h_df.age,h_df.bmi)
plt.title('Age vs BMI')
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.scatter(h_df.avg_glucose_level,h_df.bmi)
plt.title('BMI vs Glucose Level')
plt.show()
