# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
h_df=pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
h_df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
h_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
h_df.shape
# Out:
# (5110, 12)

# %%
h_df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
# In BMI some NULL values present

# %%
h_df[h_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
# No duplicates are there

# %%
h_df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
h_df['bmi'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
h_df['bmi'].plot(kind='box')
# Out:
# <Axes: >

# %%
h_df['bmi'].median()
# Out:
# 28.893236911794663

# %%
h_df['bmi']=h_df['bmi'].fillna(h_df['bmi'].median())

# %%
h_df.shape
# Out:
# (5110, 12)

# %%
h_df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
h_df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.698018     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.800000     0.000000
# 50%            91.885000    28.400000     0.000000
# 75%           114.090000    32.800000     0.000000
# max           271.740000    97.600000     1.000000

# %%
h_df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
h_df['stroke']=h_df['stroke'].apply(lambda x: 'YES' if x==1 else 'NO')

# %%
h_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level        bmi  \
# 0        Private          Urban             228.69  36.600000
# 1  Self-employed          Rural             202.21  28.893237
# 2        Private          Rural             105.92  32.500000
# 3        Private          Urban             171.23  34.400000
# 4  Self-employed          Rural             174.12  24.000000
#
#     smoking_status stroke
# 0  formerly smoked    YES
# 1     never smoked    YES
# 2     never smoked    YES
# 3           smokes    YES
# 4     never smoked    YES

# %%
num_col=h_df.select_dtypes(include=np.number).columns
cat_col=h_df.select_dtypes(exclude=np.number).columns

# %%
num_col
# Out:
# Index(['id', 'age', 'hypertension', 'heart_disease', 'avg_glucose_level',
#        'bmi'],
#       dtype='object')

# %%
cat_col
# Out:
# Index(['gender', 'ever_married', 'work_type', 'Residence_type',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
h_df['age'].plot(kind='box')
# Out:
# <Axes: >

# %%
fig,axes=plt.subplots(ncols=5, figsize=(12,3))
for column, axis in zip(num_col[1:6],axes):
    sns.boxplot(data=h_df[column],ax=axis)
    axis.set_title(column)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.hist(h_df.age)
plt.show()# histogram for age

# %%
for col in num_col[1:6]:
    plt.figure(figsize=(4,3))
    plt.hist(h_df[col])
    plt.title(col)
    plt.show()

# %%
h_df[['age', 'hypertension', 'heart_disease', 'avg_glucose_level',
       'bmi']].corr()
# Out:
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.276398       0.263796           0.238171
# hypertension       0.276398      1.000000       0.108306           0.174474
# heart_disease      0.263796      0.108306       1.000000           0.161857
# avg_glucose_level  0.238171      0.174474       0.161857           1.000000
# bmi                0.325942      0.160189       0.038899           0.168751
#
#                         bmi
# age                0.325942
# hypertension       0.160189
# heart_disease      0.038899
# avg_glucose_level  0.168751
# bmi                1.000000

# %%
correlation_matrix=h_df[['age', 'hypertension', 'heart_disease', 'avg_glucose_level',
       'bmi']].corr()
correlation_matrix
# Out:
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.276398       0.263796           0.238171
# hypertension       0.276398      1.000000       0.108306           0.174474
# heart_disease      0.263796      0.108306       1.000000           0.161857
# avg_glucose_level  0.238171      0.174474       0.161857           1.000000
# bmi                0.333398      0.167811       0.041357           0.175502
#
#                         bmi
# age                0.333398
# hypertension       0.167811
# heart_disease      0.041357
# avg_glucose_level  0.175502
# bmi                1.000000

# %%
sns.heatmap(correlation_matrix,annot=True)
# Out:
# <Axes: >

# %%
cat_col
# Out:
# Index(['gender', 'ever_married', 'work_type', 'Residence_type',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
h_df['stroke'].value_counts()
# Out:
# stroke
# NO     4861
# YES     249
# Name: count, dtype: int64

# %%
h_df['stroke'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='stroke'>

# %%
plt.figure(figsize=(4,3))
x=h_df['gender'].value_counts().plot(kind='bar')
for i in x.containers:
    x.bar_label(i)

# %%
for col in cat_col:
    plt.figure(figsize=(4,5))
    x=h_df[col].value_counts().plot(kind='bar')
    for i in x.containers:
        x.bar_label(i)
    plt.show()

# %%
max_age=h_df['age'].max()
max_age
# Out:
# 82.0

# %%
h_df[h_df['age']==max_age]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
#
# 1029  Self-employed          Rural              85.29  27.000000
# 1042  Self-employed          Urban              82.21  26.000000
# 1068        Private          Rural              96.63  26.500000
# 1350        Private          Urban              62.46  20.300000
# 1412        Private          Rural             227.28  33.300000
# 1515       Govt_job          Rural              58.30  20.400000
# 1529        Private          Urban             253.16  47.500000
# 1691        Private          Urban             144.20  35.400000
# 1769  Self-employed          Rural             211.88  28.700000
# 1839  Self-employed          Urban              77.32  24.800000
# 1951        Private          Urban              99.68  22.200000
# 2275  Self-employed          Rural             117.75  29.800000
# 2314        Private          Urban              89.83  24.700000
# 2341        Private          Urban              80.00  33.600000
# 2418  Self-employed          Rural             229.58  23.700000
# 2453        Private          Urban             214.42  33.900000
# 2633  Self-employed          Urban             243.59  24.300000
# 2876  Self-employed          Urban              79.96  27.000000
# 2979  Self-employed          Urban             107.21  27.000000
# 3108  Self-employed          Urban             161.95  30.800000
# 3167        Private          Rural              80.96  33.700000
# 3192        Private          Rural              61.47  22.900000
# 3316  Self-employed          Urban              84.78  33.600000
# 3360  Self-employed          Urban             228.92  27.900000
# 3388  Self-employed          Rural              78.00  31.300000
# 3400        Private          Urban              73.19  33.500000
# 3422  Self-employed          Rural              84.42  25.700000
# 3462  Self-employed          Urban             214.51  24.000000
# 3603  Self-employed          Urban             101.57  24.300000
# 3637        Private          Urban             226.84  25.300000
# 4088  Self-employed          Rural              88.60  32.500000
# 4094  Self-employed          Urban             111.81  19.800000
# 4164        Private          Urban             222.52  28.893237
# 4452        Private          Urban             115.71  31.100000
# 4511        Private          Urban              82.63  17.900000
# 4529        Private          Urban              57.56  27.500000
# 4590  Self-employed          Urban             101.56  31.500000
# 4716        Private          Rural              96.98  21.500000
# 4763        Private          Urban             217.57  33.500000
# 4819  Self-employed          Urban             113.45  30.300000
# 5062  Self-employed          Rural             211.58  36.900000
# 5100  Self-employed          Rural              71.97  28.300000
#
#        smoking_status stroke
# 23            Unknown    YES
# 32       never smoked    YES
# 35    formerly smoked    YES
# 42             smokes    YES
# 56       never smoked    YES
# 128   formerly smoked    YES
# 140      never smoked    YES
# 187   formerly smoked    YES
# 188   formerly smoked    YES
# 337      never smoked     NO
# 613            smokes     NO
# 670      never smoked     NO
# 767           Unknown     NO
# 992   formerly smoked     NO
# 1029     never smoked     NO
# 1042     never smoked     NO
# 1068          Unknown     NO
# 1350  formerly smoked     NO
# 1412     never smoked     NO
# 1515     never smoked     NO
# 1529          Unknown     NO
# 1691           smokes     NO
# 1769     never smoked     NO
# 1839          Unknown     NO
# 1951          Unknown     NO
# 2275     never smoked     NO
# 2314           smokes     NO
# 2341     never smoked     NO
# 2418          Unknown     NO
# 2453  formerly smoked     NO
# 2633     never smoked     NO
# 2876  formerly smoked     NO
# 2979  formerly smoked     NO
# 3108     never smoked     NO
# 3167  formerly smoked     NO
# 3192     never smoked     NO
# 3316  formerly smoked     NO
# 3360  formerly smoked     NO
# 3388  formerly smoked     NO
# 3400     never smoked     NO
# 3422          Unknown     NO
# 3462  formerly smoked     NO
# 3603           smokes     NO
# 3637  formerly smoked     NO
# 4088          Unknown     NO
# 4094  formerly smoked     NO
# 4164  formerly smoked     NO
# 4452  formerly smoked     NO
# 4511           smokes     NO
# 4529     never smoked     NO
# 4590     never smoked     NO
# 4716     never smoked     NO
# 4763  formerly smoked     NO
# 4819     never smoked     NO
# 5062     never smoked     NO
# 5100     never smoked     NO

# %%
min_age=h_df['age'].min()
min_age
# Out:
# 0.08

# %%
h_df[h_df['age']==min_age]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married work_type  \
# 1614  47350  Female  0.08             0              0           No  children
# 3295  29955    Male  0.08             0              0           No  children
#
#      Residence_type  avg_glucose_level   bmi smoking_status stroke
# 1614          Urban             139.67  14.1        Unknown     NO
# 3295          Rural              70.33  16.9        Unknown     NO

# %%
# dervied columns

# %%
def Get_Age_Group(age):

 if age <= 20:
  return "< 20"
 if age >20 and age <= 30:
    return "21-30"
 if age >30 and age <= 40:
    return "31-40"
 if age >40 and age <= 50: 
    return "41-50"
 if age > 50 and age <= 60:
    return "51-60"
 if age > 60 and age <= 70:
    return "61-70"
 if age >70 and age <= 80: 
    return "71-80"
 else:
    return "> 80"

# %%
h_df['Age_group']=h_df['age'].apply(lambda x:Get_Age_Group(x))# Age_group is new col

# %%
h_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level        bmi  \
# 0        Private          Urban             228.69  36.600000
# 1  Self-employed          Rural             202.21  28.893237
# 2        Private          Rural             105.92  32.500000
# 3        Private          Urban             171.23  34.400000
# 4  Self-employed          Rural             174.12  24.000000
#
#     smoking_status stroke Age_group
# 0  formerly smoked    YES     61-70
# 1     never smoked    YES     61-70
# 2     never smoked    YES     71-80
# 3           smokes    YES     41-50
# 4     never smoked    YES     71-80

# %%
ax=h_df['Age_group'].value_counts().plot(kind='bar')
for i in ax.containers:
    ax.bar_label(i)

# %%
# now how much stroke rate is there in each age grp

# %%
h_df.groupby(['Age_group'])['stroke'].sum()
# Out:
# Age_group
# 21-30      0
# 31-40      6
# 41-50     15
# 51-60     49
# 61-70     49
# 71-80    105
# < 20       2
# > 80      23
# Name: stroke, dtype: int64

# %%
h_df.groupby(['Age_group'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#   Age_group        bmi  avg_glucose_level        age
# 0     21-30  28.523507          94.096165  25.563303
# 1     31-40  31.223457          98.938190  35.538576
# 2     41-50  31.424162         101.011164  45.569689
# 3     51-60  31.889268         114.155310  55.340219
# 4     61-70  30.956738         119.687222  65.021886
# 5     71-80  29.140520         124.099108  76.042088
# 6      < 20  22.203600          94.345210  10.280976
# 7      > 80  27.988696         123.602500  81.482759

# %%
h_df.groupby(['stroke'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    stroke        bmi  avg_glucose_level        age
# 0       0  28.823064         104.795513  41.971545
# 1       1  30.471292         132.544739  67.728193

# %%
h_df.groupby(['ever_married'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#   ever_married        bmi  avg_glucose_level        age
# 0           No  25.214721           96.44815  22.014229
# 1          Yes  30.850749          111.23031  54.342082

# %%
h_df.groupby(['work_type'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#        work_type        bmi  avg_glucose_level        age
# 0       Govt_job  30.522063         107.779772  50.879756
# 1   Never_worked  25.545455          96.042727  16.181818
# 2        Private  30.304625         106.796844  45.503932
# 3  Self-employed  30.211871         112.645446  60.201465
# 4       children  20.038003          94.400277   6.841339

# %%
h_df.groupby(['Residence_type'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#   Residence_type        bmi  avg_glucose_level        age
# 0          Rural  28.894212         106.375235  42.900811
# 1          Urban  28.892289         105.927307  43.542126

# %%
h_df.groupby(['smoking_status'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#     smoking_status        bmi  avg_glucose_level        age
# 0          Unknown  25.666352          99.601541  30.229922
# 1  formerly smoked  30.747192         112.886079  54.929944
# 2     never smoked  29.982559         107.558092  46.744715
# 3           smokes  30.543555         108.017440  47.096324

# %%
h_df.groupby(['gender'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    gender        bmi  avg_glucose_level        age
# 0  Female  29.065758         104.057809  43.757395
# 1    Male  28.647936         109.088520  42.483385
# 2   Other  22.400000         143.330000  26.000000

# %%
h_df.groupby(['stroke','gender'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    stroke  gender        bmi  avg_glucose_level        age
# 0       0  Female  29.015952         103.051753  42.601935
# 1       0    Male  28.547711         107.255112  41.083388
# 2       0   Other  22.400000         143.330000  26.000000
# 3       1  Female  30.218333         124.414397  67.137021
# 4       1    Male  30.812360         143.159352  68.500000

# %%
h_df.groupby(['stroke','smoking_status'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    stroke   smoking_status        bmi  avg_glucose_level        age
# 0       0          Unknown  25.592847          98.810127  29.112011
# 1       0  formerly smoked  30.727692         111.175092  53.753374
# 2       0     never smoked  29.960860         106.292042  45.567703
# 3       0           smokes  30.541547         106.219906  46.212851
# 4       1          Unknown  29.351724         124.808936  65.836596
# 5       1  formerly smoked  31.014035         132.806857  68.628571
# 6       1     never smoked  30.439286         132.907222  70.311111
# 7       1           smokes  30.579487         139.987857  62.809524

# %%
h_df.groupby(['stroke','work_type'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    stroke      work_type        bmi  avg_glucose_level        age
# 0       0       Govt_job  30.575914         106.275881  50.056090
# 1       0   Never_worked  25.545455          96.042727  16.181818
# 2       0        Private  30.269001         105.113022  44.337176
# 3       0  Self-employed  30.253601         112.020504  59.241379
# 4       0       children  20.021791          94.488599   6.838949
# 5       1       Govt_job  29.364286         136.216970  66.454545
# 6       1        Private  31.057480         138.167919  67.241611
# 7       1  Self-employed  29.643396         119.894769  71.338462
# 8       1       children  30.900000          64.150000   7.660000

# %%
h_df.groupby(['stroke','Residence_type'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    stroke Residence_type        bmi  avg_glucose_level        age
# 0       0          Rural  28.843381         105.245746  41.729017
# 1       0          Urban  28.803276         104.356440  42.208062
# 2       1          Rural  30.073000         130.153947  67.570175
# 3       1          Urban  30.836697         134.563630  67.861630

# %%
h_df.groupby(['stroke','ever_married'])[['bmi','avg_glucose_level','age']].mean().reset_index()
# Out:
#    stroke ever_married        bmi  avg_glucose_level        age
# 0       0           No  25.150357          96.280208  21.286852
# 1       0          Yes  30.869947         109.492113  53.380147
# 2       1           No  29.921739         106.455172  65.355862
# 3       1          Yes  30.539247         135.983818  68.040909

# %%
num_col=['age','bmi','avg_glucose_level']

# %%
corr_matrix=h_df[num_col].corr()
corr_matrix
# Out:
#                         age       bmi  avg_glucose_level
# age                1.000000  0.333398           0.238171
# bmi                0.333398  1.000000           0.175502
# avg_glucose_level  0.238171  0.175502           1.000000

# %%
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(6,3))
plt.scatter(h_df.age,h_df.avg_glucose_level)
plt.title('Age vs Glucose Level')
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.scatter(h_df.age,h_df.bmi)
plt.title('Age vs BMI')
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.scatter(h_df.avg_glucose_level,h_df.bmi)
plt.title('BMI vs Glucose Level')
plt.show()
